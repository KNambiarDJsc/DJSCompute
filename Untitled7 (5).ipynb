# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
# correct the code below
# refer pandas documentation for the correct syntax
df = pd.read_csv('/content/breast_cancer_survival.csv')

# %%
df.head()
#similarly the first 31 rows
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit Patient_Status
# ...

# %%
#Check if the dataset has null values and specify those columns
#Enter code below
null_columns = df.columns[df.isnull().any()]
null_columns
null_count = df[null_columns].isnull().sum()
null_count
# Out:
# Date_of_Last_Visit    17
# Patient_Status        13
# dtype: int64

# %%
# Drop the entire column if the percentage of null values to the total rows is greater than 10%
# If less than 10% then drop the null values directly
#Enter code below
drop_len = len(df)*(10/100)
columns_dropped = []
for col in df.columns:
  null_count = df[col].isnull().sum()
  if null_count>=drop_len:
    columns_dropped.append(col)
df.drop(columns = columns_dropped,inplace =True )
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 317 non-null    int64
#  1   Gender              317 non-null    object
#  2   Protein1            317 non-null    float64
#  3   Protein2            317 non-null    float64
#  4   Protein3            317 non-null    float64
#  5   Protein4            317 non-null    float64
#  6   Tumour_Stage        317 non-null    object
#  7   Histology           317 non-null    object
#  8   ER status           317 non-null    object
#  9   PR status           317 non-null    object
#  10  HER2 status         317 non-null    object
#  11  Surgery_type        317 non-null    object
#  12  Date_of_Surgery     317 non-null    object
#  13  Date_of_Last_Visit  317 non-null    object
#  14  Patient_Status      317 non-null    object
# ...

# %%
#Find and eliminate duplicate values if any
df.duplicated()
df.drop_duplicates(inplace = True)

# %%
#Find the number of patients of each Tumour Stage and visualize it using a pie-chart.
stage_counts = df['Tumour_Stage'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(stage_counts,labels=stage_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Patients by Tumour Stage")
plt.show()

# %%
df.value_counts("Tumour_Stage")
# Out:
# Tumour_Stage
# II     180
# III     77
# I       60
# dtype: int64

# %%
# Make a historgram of counts of people with different Tumor Stages
plt.figure(figsize=(8,8))
plt.hist(df['Tumour_Stage'],align='left',rwidth=1.2,label='d' )
plt.xlabel('Tumour Stage')
plt.ylabel('Count')
plt.title('Histogram of Tumour Stage Counts')
plt.show()

# %%
#Rename the Patient_Status as Target and Give labels Alive = 1 and Dead = 0
df.rename(columns={'Patient_Status': 'Target'}, inplace=True)
df['Target'] = df['Target'].map({'Alive': 1, 'Dead': 0})
df
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
#Bin the age column
# Create a new column 'age_bins' with the Age values binned as [0, 20, 40, 60, 80, 100]
#https://pandas.pydata.org/docs/reference/api/pandas.cut.html
#I created bin_ages
bin_ages = [0, 20, 40, 60, 80, 100]
df['age_bins'] = pd.cut(df['Age'], bins=bin_ages, labels=['0-20', '21-40', '41-60', '61-80', '81-100'])
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit  Target age_bins
# ...

# %%
#plot the count of people in each age bin using a histogram
plt.figure(figsize=(10, 8))
sns.histplot(df['age_bins'], bins=bin_ages, kde=True)
plt.xlabel('Age Bins')
plt.ylabel('Count')
plt.title('Histogram of People in Each Age Bin')
plt.show()

# %%
# Make a chart showcasing number of male and female patients in the given data, explain why the data has more values of one gender over the other
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(6, 4))
gender_counts.plot(kind='bar', color=['pink', 'blue'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution of Patients')
plt.show()
#There are way more female patients than male.This might be caused due to the bias during the data collection causes the same.Another reason might be small dataset.

# %%
# diplay counts of pateints with differnent breast cancer types (Histology)
df['Histology'].value_counts()
# Out:
# Infiltrating Ductal Carcinoma     224
# Infiltrating Lobular Carcinoma     81
# Mucinous Carcinoma                 12
# Name: Histology, dtype: int64

# %%
# Find out the most frequent surgery performed
most_frequent_surgery = df['Date_of_Surgery'].value_counts().idxmax()

print(f"The most frequent surgery performed is: {most_frequent_surgery}")
# Out:
# The most frequent surgery performed is: 06-Dec-18

# %%
# Find out prevalent surgery types for each type of breast cancer
prevalent_surgeries= df.groupby('Histology')['Surgery_type'].apply(lambda x: x.value_counts().idxmax())

print("Prevalent surgery types for each breast cancer histology:")
print(prevalent_surgeries)
# Out:
# Prevalent surgery types for each breast cancer histology:
# Histology
# Infiltrating Ductal Carcinoma          Other
# Infiltrating Lobular Carcinoma         Other
# Mucinous Carcinoma                Lumpectomy
# Name: Surgery_type, dtype: object

# %%
# find out the co-realtion between age protien levels and the type of breast cancer (make a heatmap)
selected_columns = ['Age', 'Protein1', 'Protein2', 'Protein3','Protein4','Histology']
selected_df = df[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_df.corr()

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap: Age, Protein Levels, and Histology')
plt.show()
# Out:
# <ipython-input-32-aecffed30fc5>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = selected_df.corr()

# %% [markdown]
# Model

# %%
df['Survival_status']=df['Target'].astype(bool)
df
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
X = df.drop('Survival_status',axis=1)
Y = df['Survival_status']
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size = 0.33,random_state =42)

# %%
df['Gender'] = df['Gender'].replace({'Male': 0, 'Female': 1,})
df
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
pip install lazypredict

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE      0.95      2.15      0.01     -0.05           II
# 1   54  FEMALE      0.00      1.38     -0.50     -0.51           II
# 2   63  FEMALE     -0.52      1.76     -0.37      0.01           II
# 3   78  FEMALE     -0.88      0.13     -0.37      0.13            I
# 4   42  FEMALE      0.23      1.75     -0.54     -0.39           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit  Target age_bins  Survival_status
# ...

# %%
columns_ = ['Histology', 'Tumour_Stage', 'Surgery_type','Gender']
df2= pd.get_dummies(df, columns=columns_, drop_first=False)
df2
# Out:
#      Age  Protein1  Protein2  Protein3  Protein4  Target age_bins  \
# 0     42      0.95      2.15      0.01     -0.05       1    41-60
# 1     54      0.00      1.38     -0.50     -0.51       0    41-60
# 2     63     -0.52      1.76     -0.37      0.01       1    61-80
# 3     78     -0.88      0.13     -0.37      0.13       1    61-80
# 4     42      0.23      1.75     -0.54     -0.39       1    41-60
# ..   ...       ...       ...       ...       ...     ...      ...
# 329   59      0.02      1.40      0.02      0.28       1    41-60
# 330   41      0.10     -0.47      0.47     -0.52       1    41-60
# 331   54      0.75      1.64     -0.33      0.86       0    41-60
# 332   74      0.97      1.43     -0.37     -0.11       1    61-80
# 333   66      0.29      1.40      0.32      0.84       0    61-80
#
#      Survival_status  Histology_Infiltrating Ductal Carcinoma  \
# 0                  1                                        1
# ...

# %%
df['Survival_status'] = df['Survival_status'].astype(int)

# %%
df2 = df2.drop('age_bins',axis=1)
df2 = df2.drop('Survival_status',axis=1)

# %%
X = df2.drop('Target',axis=1)
Y = df2['Target']
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42)

# %%
scaler = StandardScaler()

X_train_s = scaler.fit_transform(X_train)
X_test_s = scaler.transform(X_test)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train_s, X_test_s, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 24.91it/s]
# [LightGBM] [Info] Number of positive: 170, number of negative: 42
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 359
# [LightGBM] [Info] Number of data points in the train set: 212, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.801887 -> initscore=1.398129
# [LightGBM] [Info] Start training from score 1.398129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.84               0.61     0.61      0.80
# KNeighborsClassifier               0.81               0.56     0.56      0.77
# AdaBoostClassifier                 0.77               0.55     0.55      0.75
# NearestCentroid                    0.61               0.55     0.55      0.65
# PassiveAggressiveClassifier        0.70               0.54     0.54      0.71
# ExtraTreeClassifier                0.72               0.54     0.54      0.72
# XGBClassifier                      0.78               0.54     0.54      0.75
# LabelPropagation                   0.69               0.52     0.52      0.69
# LabelSpreading                     0.69               0.52     0.52      0.69
# SGDClassifier                      0.74               0.52     0.52      0.72
# Perceptron                         0.73               0.51     0.51      0.71
# ...

# %%
param_grid={
 'class_weight' : [None,'balanced'],
  'penalty': ['l1', 'l2', 'elasticnet', None],
  'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag'],
  'max_iter': [80,100,200]
}

# %%
model=LogisticRegression()
cv=GridSearchCV(model,param_grid,cv=5,scoring='accuracy')
cv.fit(X_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_iter': [80, 100, 200],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag']},
#              scoring='accuracy')

# %%
y_pred=cv.predict(X_test_s)
logistic_score=accuracy_score(y_pred,y_test)
logistic_score
# Out:
# 0.8095238095238095
